# %%
import pandas as pd

# %%
data1="full_parse.csv"
data = pd.read_csv(data1, sep=";")

# %%
data.head()
# Out:
#          date                                                url  \
# 0  2022-02-24  russia_ukraine_warning_update_initial_russian_...
# 1  2022-02-25  russia_ukraine_warning_update_russian_offensiv...
# 2  2022-02-26  russia_ukraine_warning_update_russian_offensiv...
# 3  2022-02-27  russia_ukraine_warning_update_russian_offensiv...
# 4  2022-02-28  russian_offensive_campaign_assessment_february...
#
#                                            main_text  \
# 0  <div class="field field-name-body field-type-t...
# 1  <div class="field field-name-body field-type-t...
# 2  <div class="field field-name-body field-type-t...
# 3  <div class="field field-name-body field-type-t...
# 4  <div class="field field-name-body field-type-t...
#
#                                         main_html_v2  \
# 0  <div class="field field-name-body field-type-t...
# 1  <div class="field field-name-body field-type-t...
# 2  <div class="field field-name-body field-type-t...
# ...

# %%
data.shape
# Out:
# (335, 10)

# %%
data.rename(columns={'date': 'day_datetime'}, inplace=True)

# %%
data2= pd.read_csv('df_weather+alarms_merged.csv')

# %%
data2.head()
# Out:
#    Unnamed: 0           city_resolvedAddress day_datetime  day_datetimeEpoch  \
# 0           0  Луцьк, Луцький район, Україна   2022-02-24         1645653600
# 1           1  Луцьк, Луцький район, Україна   2022-02-24         1645653600
# 2           2  Луцьк, Луцький район, Україна   2022-02-24         1645653600
# 3           3  Луцьк, Луцький район, Україна   2022-02-24         1645653600
# 4           4  Луцьк, Луцький район, Україна   2022-02-24         1645653600
#
#    day_tempmax  day_tempmin  day_temp  day_dew  day_humidity  day_precip  ...  \
# 0          4.9          0.7       2.6      0.0          83.7       0.118  ...
# 1          4.9          0.7       2.6      0.0          83.7       0.118  ...
# 2          4.9          0.7       2.6      0.0          83.7       0.118  ...
# 3          4.9          0.7       2.6      0.0          83.7       0.118  ...
# 4          4.9          0.7       2.6      0.0          83.7       0.118  ...
#
# ...

# %%
merged_df = pd.merge(data, data2, how='left', on='day_datetime')

# %%
merged_df.shape
# Out:
# (194524, 69)

# %%
merged_df.to_csv('weather_alarms_tfidf.csv')
